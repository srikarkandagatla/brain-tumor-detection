# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset

# %%
# !unzip brain-tumor-mri-dataset.zip

# %%
import os
import cv2
import time
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
training_set = '/content/Training'
testing_set = '/content/Testing'

# %%
input_shape = (150, 150, 3)

# %%
# Initializing the Neural Network Model using Tensorflow and Keras
# This is an Alternative way of initializing the Neural Network
'''
from tf.keras.models import Sequential
model = Sequential()
'''

# I chose this line of code which in fact efficient to read and run
BTD = tf.keras.models.Sequential()

#BTD Stands for "Brain Tumor Detection"

# %%
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Flatten())

# %%
BTD.add(Dense(512, activation = 'relu'))
BTD.add(Dense(256, activation = 'relu'))

# Dropout layer with droupout rate set to 0.5
BTD.add(Dropout(0.5))
BTD.add(Dense(128, activation = 'relu'))
BTD.add(Dense(64, activation = 'relu'))
BTD.add(Dense(4, activation = 'softmax'))

# Compiling the Neural Network
BTD.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
BTD.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      9248
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 32)        9248
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 34, 34, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 64)        36928
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 64)        36928
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 64)        36928
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 929316 (3.55 MB)
# Trainable params: 929316 (3.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
image_data_generator = ImageDataGenerator(rescale = 1./255,
                                          rotation_range = 40,
                                          height_shift_range = 0.2,
                                          width_shift_range = 0.2,
                                          shear_range = 0.2,
                                          zoom_range = 0.2,
                                          horizontal_flip = True,
                                          fill_mode = 'nearest')

# %%
# Data augmentation is applied to training images using a batch size of 32, and the order of images is randomized
# The images will undergo resizing to dimensions of (150, 150)
# Since this is a categorical classification problem, the class mode is set to 'categorical'
# The labels will be one-hot encoded

training_images = image_data_generator.flow_from_directory(training_set,
                                                           batch_size = 32,
                                                           target_size = (150, 150),
                                                           shuffle = True,
                                                           class_mode = 'categorical')
# Out:
# Found 5712 images belonging to 4 classes.

# %%
validation_data_generator = ImageDataGenerator(rescale = 1./255)

# %%
testing_images = validation_data_generator.flow_from_directory(testing_set,
                                                               batch_size = 32,
                                                               target_size = (150, 150),
                                                               shuffle = False,
                                                               class_mode = 'categorical')
# Out:
# Found 1311 images belonging to 4 classes.

# %%
class CustomCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}

        val_accuracy = logs.get('val_accuracy')
        if val_accuracy is not None and val_accuracy >= 0.85:
            print(f"\nValidation accuracy reached {val_accuracy * 100:.2f}%. Training is stopped.")
            self.model.stop_training = True

custom_callback = CustomCallback()

# %%
start_time = time.time()

BTD.fit(training_images,
        epochs = 1000,
        steps_per_epoch = len(training_images),
        validation_data = testing_images,
        callbacks = [custom_callback])

end_time = time.time()
# Out:
# Epoch 1/1000
# 179/179 [==============================] - 70s 281ms/step - loss: 1.2726 - accuracy: 0.3587 - val_loss: 1.0537 - val_accuracy: 0.4958
# Epoch 2/1000
# 179/179 [==============================] - 48s 267ms/step - loss: 1.0835 - accuracy: 0.4750 - val_loss: 1.0588 - val_accuracy: 0.4569
# Epoch 3/1000
# 179/179 [==============================] - 47s 264ms/step - loss: 1.0335 - accuracy: 0.5054 - val_loss: 1.9605 - val_accuracy: 0.3432
# Epoch 4/1000
# 179/179 [==============================] - 47s 260ms/step - loss: 0.9982 - accuracy: 0.5345 - val_loss: 1.2320 - val_accuracy: 0.4615
# Epoch 5/1000
# 179/179 [==============================] - 45s 252ms/step - loss: 0.9717 - accuracy: 0.5679 - val_loss: 1.2783 - val_accuracy: 0.4470
# Epoch 6/1000
# 179/179 [==============================] - 47s 263ms/step - loss: 0.9371 - accuracy: 0.6099 - val_loss: 1.3009 - val_accuracy: 0.4355
# Epoch 7/1000
# 179/179 [==============================] - 45s 250ms/step - loss: 0.9101 - accuracy: 0.6241 - val_loss: 1.0103 - val_accuracy: 0.5553
# Epoch 8/1000
# 179/179 [==============================] - 46s 258ms/step - loss: 0.8697 - accuracy: 0.6401 - val_loss: 1.1717 - val_accuracy: 0.5156
# Epoch 9/1000
# 179/179 [==============================] - 45s 253ms/step - loss: 0.8574 - accuracy: 0.6495 - val_loss: 1.0449 - val_accuracy: 0.5378
# Epoch 10/1000
# 179/179 [==============================] - 46s 259ms/step - loss: 0.8150 - accuracy: 0.6733 - val_loss: 1.2998 - val_accuracy: 0.4294
# Epoch 11/1000
# 179/179 [==============================] - 45s 249ms/step - loss: 0.8059 - accuracy: 0.6887 - val_loss: 1.2882 - val_accuracy: 0.4630
# Epoch 12/1000
# 179/179 [==============================] - 45s 252ms/step - loss: 0.7628 - accuracy: 0.7013 - val_loss: 1.2340 - val_accuracy: 0.5141
# Epoch 13/1000
# 179/179 [==============================] - 47s 259ms/step - loss: 0.7383 - accuracy: 0.7174 - val_loss: 1.1167 - val_accuracy: 0.5530
# Epoch 14/1000
# 179/179 [==============================] - 48s 270ms/step - loss: 0.7311 - accuracy: 0.7300 - val_loss: 1.0767 - val_accuracy: 0.5744
# Epoch 15/1000
# 179/179 [==============================] - 46s 256ms/step - loss: 0.6738 - accuracy: 0.7425 - val_loss: 1.2305 - val_accuracy: 0.5019
# Epoch 16/1000
# 179/179 [==============================] - 46s 260ms/step - loss: 0.6562 - accuracy: 0.7481 - val_loss: 1.2025 - val_accuracy: 0.5820
# Epoch 17/1000
# 179/179 [==============================] - 46s 255ms/step - loss: 0.6458 - accuracy: 0.7600 - val_loss: 0.6202 - val_accuracy: 0.7529
# Epoch 18/1000
# 179/179 [==============================] - 49s 273ms/step - loss: 0.6136 - accuracy: 0.7754 - val_loss: 0.9265 - val_accuracy: 0.6552
# Epoch 19/1000
# 179/179 [==============================] - 45s 251ms/step - loss: 0.5939 - accuracy: 0.7785 - val_loss: 1.0153 - val_accuracy: 0.6079
# Epoch 20/1000
# 179/179 [==============================] - 46s 259ms/step - loss: 0.5777 - accuracy: 0.7862 - val_loss: 0.7987 - val_accuracy: 0.7018
# Epoch 21/1000
# 179/179 [==============================] - 46s 256ms/step - loss: 0.5528 - accuracy: 0.7945 - val_loss: 1.3732 - val_accuracy: 0.5294
# Epoch 22/1000
# 179/179 [==============================] - 49s 272ms/step - loss: 0.5368 - accuracy: 0.8018 - val_loss: 1.1747 - val_accuracy: 0.6034
# Epoch 23/1000
# 179/179 [==============================] - 45s 254ms/step - loss: 0.5212 - accuracy: 0.8086 - val_loss: 1.1489 - val_accuracy: 0.6240
# Epoch 24/1000
# 179/179 [==============================] - 47s 262ms/step - loss: 0.4916 - accuracy: 0.8211 - val_loss: 0.6965 - val_accuracy: 0.7788
# Epoch 25/1000
# 179/179 [==============================] - 48s 268ms/step - loss: 0.4538 - accuracy: 0.8412 - val_loss: 0.7035 - val_accuracy: 0.7765
# Epoch 26/1000
# 179/179 [==============================] - 48s 269ms/step - loss: 0.4400 - accuracy: 0.8423 - val_loss: 0.4661 - val_accuracy: 0.8360
# Epoch 27/1000
# 179/179 [==============================] - 45s 251ms/step - loss: 0.4355 - accuracy: 0.8465 - val_loss: 0.7760 - val_accuracy: 0.7292
# Epoch 28/1000
# 179/179 [==============================] - 45s 252ms/step - loss: 0.4112 - accuracy: 0.8514 - val_loss: 0.4623 - val_accuracy: 0.8352
# Epoch 29/1000
# 179/179 [==============================] - ETA: 0s - loss: 0.4116 - accuracy: 0.8554
# Validation accuracy reached 88.25%. Training is stopped.
# 179/179 [==============================] - 46s 257ms/step - loss: 0.4116 - accuracy: 0.8554 - val_loss: 0.3209 - val_accuracy: 0.8825

# %%
total_time = end_time - start_time
print(f"Total time taken for training: {total_time:.2f} seconds")
# Out:
# Total time taken for training: 1772.09 seconds

# %%
# Training Loss Vs Validation Loss
# I have mentioned two different ways to plot the graphs, please take a look on both
loss = BTD.history.history['loss']
val_loss = BTD.history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label = 'loss')
plt.plot(epochs, val_loss, 'r', label = 'val_loss')
plt.title('Training Vs Validation Loss')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Accuracy Vs Validation Accuracy
# This is other way of plotting the plot
losses = pd.DataFrame(BTD.history.history)
losses[['accuracy','val_accuracy']].plot()
plt.title('Accuracy Vs Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
losses = pd.DataFrame(BTD.history.history)
losses[['accuracy', 'val_accuracy']] *= 100  # Convert to percentage
losses[['accuracy', 'val_accuracy']].plot()
plt.title('Accuracy Vs Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy (%)')  # Modify the y-axis label
plt.legend()
plt.show()

# %%
predictions = BTD.predict(testing_images)
print(predictions)
# Out:
# 41/41 [==============================] - 3s 74ms/step
# [[3.6229339e-01 8.9619122e-02 4.7335950e-01 7.4728005e-02]
#  [6.7660332e-01 4.3176305e-02 4.6651591e-02 2.3356880e-01]
#  [9.9480599e-01 1.3515980e-03 7.8609819e-04 3.0563248e-03]
#  ...
#  [1.2538907e-02 3.0423349e-02 2.1261459e-02 9.3577623e-01]
#  [5.2171815e-02 6.7501467e-01 4.7705611e-03 2.6804289e-01]
#  [1.9200013e-03 1.1183292e-02 2.3153508e-03 9.8458129e-01]]

# %%
print(BTD.evaluate(testing_images))
# Out:
# 41/41 [==============================] - 2s 55ms/step - loss: 0.3209 - accuracy: 0.8825
# [0.32092371582984924, 0.8825324177742004]

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    testing_set,
    target_size=(150, 150),
    batch_size = 32,
    class_mode = 'categorical',
    shuffle=False
)

true_labels = test_generator.classes
num_samples = len(true_labels)

num_batches = num_samples // test_generator.batch_size
print("Total number of samples:", num_samples)
print("\n")

print("Number of batches:", num_batches)
predictions = BTD.predict(test_generator, steps = num_batches, verbose = 1)
# When verbose = 1, it will show a progress bar during the prediction
print("40 Batches are processed")
print("\n")
print("Number of batches:", num_batches + 1)
predictions = BTD.predict(test_generator, steps = num_batches + 1, verbose = 1)
print("41 Batches are processed (Same Batches)")
print("\n")
print("Number of batches:", num_batches + 1)
predictions = BTD.predict(test_generator, steps = num_samples // test_generator.batch_size + 1, verbose = 1)
predicted_labels = np.argmax(predictions, axis = 1)
print("41 Batches are processed (Same Batches)")
print("\n")

actual_label = len(true_labels)
pred_label = len(predicted_labels)
print(f"True Labels: {actual_label}\nPredicted Labels: {pred_label}")
cm = confusion_matrix(true_labels, predicted_labels)
class_names = ["Glioma", "Meningioma", "Notumor", "Pituitary"]

def plot_confusion_matrix(cm, classes, normalize = False, title = 'Confusion matrix', cmap = plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("\n")
        print("First Matrix is Normalized Confusion Matrix\n")
    else:
        print('Second Confusion Matrix is Without Normalization')

    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()

plt.figure()
plot_confusion_matrix(cm, classes = class_names, normalize = True, title = 'Normalized Confusion Matrix')

plt.figure()
plot_confusion_matrix(cm, classes = class_names, normalize = False, title = 'Confusion Matrix without Normalization')

plt.show()
# Out:
# Found 1311 images belonging to 4 classes.
# Total number of samples: 1311
#
#
# Number of batches: 40
# 40/40 [==============================] - 4s 95ms/step
# 40 Batches are processed
#
#
# Number of batches: 41
# 41/41 [==============================] - 2s 53ms/step
# 41 Batches are processed (Same Batches)
#
#
# Number of batches: 41
# 41/41 [==============================] - 3s 70ms/step
# 41 Batches are processed (Same Batches)
#
#
# True Labels: 1311
# Predicted Labels: 1311
#
#
# First Matrix is Normalized Confusion Matrix
#
# Second Confusion Matrix is Without Normalization
