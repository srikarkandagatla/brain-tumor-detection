# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset

# %%
# !unzip brain-tumor-mri-dataset.zip

# %%
import os
import cv2
import time
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
training_set = '/content/Training'
testing_set = '/content/Testing'

# %%
input_shape = (192, 192, 3)

# %%
# Initializing the Neural Network Model using Tensorflow and Keras
# This is an Alternative way of initializing the Neural Network
'''
from tf.keras.models import Sequential
model = Sequential()
'''

# I chose this line of code which in fact efficient to read and run
BTD = tf.keras.models.Sequential()

#BTD Stands for "Brain Tumor Detection"

# %%
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(32, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(Conv2D(64, (3,3), input_shape = input_shape, activation = 'relu'))
BTD.add(MaxPooling2D(pool_size = (2,2)))

# %%
BTD.add(Flatten())

# %%
BTD.add(Dense(512, activation = 'relu'))
BTD.add(Dense(256, activation = 'relu'))

# Dropout layer with droupout rate set to 0.5
BTD.add(Dropout(0.5))
BTD.add(Dense(128, activation = 'relu'))
BTD.add(Dense(64, activation = 'relu'))
BTD.add(Dense(4, activation = 'softmax'))

# Compiling the Neural Network
BTD.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
BTD.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 190, 190, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 188, 188, 32)      9248
#
#  max_pooling2d (MaxPooling2  (None, 94, 94, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 92, 92, 32)        9248
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        36928
#
#  conv2d_6 (Conv2D)           (None, 39, 39, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 19, 19, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 17, 17, 64)        36928
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 64)        36928
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1584676 (6.05 MB)
# Trainable params: 1584676 (6.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
image_data_generator = ImageDataGenerator(rescale = 1./255,
                                          rotation_range = 40,
                                          height_shift_range = 0.2,
                                          width_shift_range = 0.2,
                                          shear_range = 0.2,
                                          zoom_range = 0.2,
                                          horizontal_flip = True,
                                          fill_mode = 'nearest')

# %%
# Data augmentation is applied to training images using a batch size of 32, and the order of images is randomized
# The images will undergo resizing to dimensions of (150, 150)
# Since this is a categorical classification problem, the class mode is set to 'categorical'
# The labels will be one-hot encoded

training_images = image_data_generator.flow_from_directory(training_set,
                                                           batch_size = 32,
                                                           target_size = (192, 192),
                                                           shuffle = True,
                                                           class_mode = 'categorical')
# Out:
# Found 5712 images belonging to 4 classes.

# %%
validation_data_generator = ImageDataGenerator(rescale = 1./255)

# %%
testing_images = validation_data_generator.flow_from_directory(testing_set,
                                                               batch_size = 32,
                                                               target_size = (192, 192),
                                                               shuffle = False,
                                                               class_mode = 'categorical')
# Out:
# Found 1311 images belonging to 4 classes.

# %%
class CustomCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}

        val_accuracy = logs.get('val_accuracy')
        if val_accuracy is not None and val_accuracy >= 0.95:
          print("\n")
          print(f"\nValidation accuracy reached {val_accuracy * 100:.2f}%. Training is stopped.")
          self.model.stop_training = True

custom_callback = CustomCallback()

# %%
start_time = time.time()

BTD.fit(training_images,
        epochs = 1000,
        steps_per_epoch = len(training_images),
        validation_data = testing_images,
        callbacks = [custom_callback])

end_time = time.time()
# Out:
# Epoch 1/1000
# 179/179 [==============================] - 91s 390ms/step - loss: 1.1837 - accuracy: 0.4100 - val_loss: 1.0481 - val_accuracy: 0.4783
# Epoch 2/1000
# 179/179 [==============================] - 67s 376ms/step - loss: 1.0501 - accuracy: 0.5019 - val_loss: 1.1280 - val_accuracy: 0.4584
# Epoch 3/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 1.0018 - accuracy: 0.5625 - val_loss: 1.0821 - val_accuracy: 0.5141
# Epoch 4/1000
# 179/179 [==============================] - 67s 375ms/step - loss: 0.9430 - accuracy: 0.6108 - val_loss: 1.1670 - val_accuracy: 0.4805
# Epoch 5/1000
# 179/179 [==============================] - 67s 371ms/step - loss: 0.8789 - accuracy: 0.6395 - val_loss: 1.2111 - val_accuracy: 0.4615
# Epoch 6/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.8458 - accuracy: 0.6549 - val_loss: 1.1545 - val_accuracy: 0.4851
# Epoch 7/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.7892 - accuracy: 0.6882 - val_loss: 0.7529 - val_accuracy: 0.7086
# Epoch 8/1000
# 179/179 [==============================] - 69s 387ms/step - loss: 0.7761 - accuracy: 0.6936 - val_loss: 0.7273 - val_accuracy: 0.7201
# Epoch 9/1000
# 179/179 [==============================] - 69s 387ms/step - loss: 0.7149 - accuracy: 0.7300 - val_loss: 0.8067 - val_accuracy: 0.6568
# Epoch 10/1000
# 179/179 [==============================] - 68s 377ms/step - loss: 0.6945 - accuracy: 0.7386 - val_loss: 0.7257 - val_accuracy: 0.7239
# Epoch 11/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.7025 - accuracy: 0.7290 - val_loss: 0.7793 - val_accuracy: 0.6827
# Epoch 12/1000
# 179/179 [==============================] - 67s 376ms/step - loss: 0.6749 - accuracy: 0.7411 - val_loss: 0.8035 - val_accuracy: 0.6583
# Epoch 13/1000
# 179/179 [==============================] - 67s 374ms/step - loss: 0.6148 - accuracy: 0.7593 - val_loss: 0.7366 - val_accuracy: 0.6766
# Epoch 14/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.5841 - accuracy: 0.7796 - val_loss: 0.7193 - val_accuracy: 0.7277
# Epoch 15/1000
# 179/179 [==============================] - 67s 377ms/step - loss: 0.5814 - accuracy: 0.7782 - val_loss: 0.6926 - val_accuracy: 0.7033
# Epoch 16/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.5524 - accuracy: 0.7959 - val_loss: 1.5103 - val_accuracy: 0.6079
# Epoch 17/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.5696 - accuracy: 0.7861 - val_loss: 1.0415 - val_accuracy: 0.6125
# Epoch 18/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.5520 - accuracy: 0.7943 - val_loss: 0.6134 - val_accuracy: 0.7422
# Epoch 19/1000
# 179/179 [==============================] - 71s 397ms/step - loss: 0.5170 - accuracy: 0.8090 - val_loss: 0.6545 - val_accuracy: 0.7353
# Epoch 20/1000
# 179/179 [==============================] - 67s 374ms/step - loss: 0.5025 - accuracy: 0.8150 - val_loss: 0.5707 - val_accuracy: 0.7590
# Epoch 21/1000
# 179/179 [==============================] - 67s 371ms/step - loss: 0.4932 - accuracy: 0.8192 - val_loss: 0.5685 - val_accuracy: 0.7757
# Epoch 22/1000
# 179/179 [==============================] - 67s 374ms/step - loss: 0.4737 - accuracy: 0.8227 - val_loss: 0.6940 - val_accuracy: 0.7124
# Epoch 23/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.4766 - accuracy: 0.8214 - val_loss: 0.6408 - val_accuracy: 0.7818
# Epoch 24/1000
# 179/179 [==============================] - 67s 376ms/step - loss: 0.4666 - accuracy: 0.8277 - val_loss: 0.4456 - val_accuracy: 0.8070
# Epoch 25/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.4558 - accuracy: 0.8391 - val_loss: 0.4880 - val_accuracy: 0.7925
# Epoch 26/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.4573 - accuracy: 0.8377 - val_loss: 0.4927 - val_accuracy: 0.8002
# Epoch 27/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.4394 - accuracy: 0.8409 - val_loss: 0.4631 - val_accuracy: 0.8093
# Epoch 28/1000
# 179/179 [==============================] - 69s 387ms/step - loss: 0.4507 - accuracy: 0.8337 - val_loss: 0.4818 - val_accuracy: 0.7994
# Epoch 29/1000
# 179/179 [==============================] - 68s 382ms/step - loss: 0.4121 - accuracy: 0.8477 - val_loss: 0.4645 - val_accuracy: 0.8291
# Epoch 30/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.4125 - accuracy: 0.8456 - val_loss: 0.4407 - val_accuracy: 0.8177
# Epoch 31/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.3999 - accuracy: 0.8519 - val_loss: 0.5281 - val_accuracy: 0.7757
# Epoch 32/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.4013 - accuracy: 0.8508 - val_loss: 0.4838 - val_accuracy: 0.8192
# Epoch 33/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.3812 - accuracy: 0.8599 - val_loss: 0.5924 - val_accuracy: 0.7948
# Epoch 34/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.3865 - accuracy: 0.8545 - val_loss: 0.3615 - val_accuracy: 0.8535
# Epoch 35/1000
# 179/179 [==============================] - 66s 368ms/step - loss: 0.3525 - accuracy: 0.8715 - val_loss: 0.3880 - val_accuracy: 0.8490
# Epoch 36/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.3672 - accuracy: 0.8643 - val_loss: 0.3645 - val_accuracy: 0.8604
# Epoch 37/1000
# 179/179 [==============================] - 67s 371ms/step - loss: 0.3686 - accuracy: 0.8617 - val_loss: 0.4479 - val_accuracy: 0.8162
# Epoch 38/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.3426 - accuracy: 0.8813 - val_loss: 0.4752 - val_accuracy: 0.8169
# Epoch 39/1000
# 179/179 [==============================] - 69s 384ms/step - loss: 0.3420 - accuracy: 0.8766 - val_loss: 0.3862 - val_accuracy: 0.8497
# Epoch 40/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.3323 - accuracy: 0.8817 - val_loss: 0.3848 - val_accuracy: 0.8482
# Epoch 41/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.3178 - accuracy: 0.8794 - val_loss: 0.3837 - val_accuracy: 0.8566
# Epoch 42/1000
# 179/179 [==============================] - 67s 371ms/step - loss: 0.3105 - accuracy: 0.8839 - val_loss: 0.4087 - val_accuracy: 0.8581
# Epoch 43/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.3127 - accuracy: 0.8867 - val_loss: 0.2809 - val_accuracy: 0.8886
# Epoch 44/1000
# 179/179 [==============================] - 66s 368ms/step - loss: 0.3038 - accuracy: 0.8918 - val_loss: 0.3557 - val_accuracy: 0.8619
# Epoch 45/1000
# 179/179 [==============================] - 67s 376ms/step - loss: 0.3142 - accuracy: 0.8803 - val_loss: 0.3890 - val_accuracy: 0.8528
# Epoch 46/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.2911 - accuracy: 0.8964 - val_loss: 0.3502 - val_accuracy: 0.8673
# Epoch 47/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.2727 - accuracy: 0.9051 - val_loss: 0.6936 - val_accuracy: 0.7979
# Epoch 48/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.3058 - accuracy: 0.8918 - val_loss: 0.3615 - val_accuracy: 0.8635
# Epoch 49/1000
# 179/179 [==============================] - 68s 382ms/step - loss: 0.2820 - accuracy: 0.9056 - val_loss: 0.3445 - val_accuracy: 0.8757
# Epoch 50/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.2765 - accuracy: 0.9023 - val_loss: 0.3423 - val_accuracy: 0.8818
# Epoch 51/1000
# 179/179 [==============================] - 67s 375ms/step - loss: 0.2652 - accuracy: 0.9020 - val_loss: 0.3692 - val_accuracy: 0.8635
# Epoch 52/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.2667 - accuracy: 0.9049 - val_loss: 0.3118 - val_accuracy: 0.8863
# Epoch 53/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.2633 - accuracy: 0.9035 - val_loss: 0.3562 - val_accuracy: 0.8635
# Epoch 54/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.2654 - accuracy: 0.9027 - val_loss: 0.2139 - val_accuracy: 0.9123
# Epoch 55/1000
# 179/179 [==============================] - 66s 370ms/step - loss: 0.2500 - accuracy: 0.9083 - val_loss: 0.2178 - val_accuracy: 0.9184
# Epoch 56/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.2508 - accuracy: 0.9086 - val_loss: 0.3107 - val_accuracy: 0.8924
# Epoch 57/1000
# 179/179 [==============================] - 66s 372ms/step - loss: 0.2586 - accuracy: 0.9042 - val_loss: 0.4390 - val_accuracy: 0.8352
# Epoch 58/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.2407 - accuracy: 0.9126 - val_loss: 0.2833 - val_accuracy: 0.8871
# Epoch 59/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.2550 - accuracy: 0.9095 - val_loss: 0.2279 - val_accuracy: 0.9153
# Epoch 60/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.2504 - accuracy: 0.9114 - val_loss: 0.1880 - val_accuracy: 0.9176
# Epoch 61/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.2350 - accuracy: 0.9175 - val_loss: 0.2128 - val_accuracy: 0.9108
# Epoch 62/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.2216 - accuracy: 0.9181 - val_loss: 0.2021 - val_accuracy: 0.9138
# Epoch 63/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.2353 - accuracy: 0.9167 - val_loss: 0.2464 - val_accuracy: 0.9016
# Epoch 64/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.2287 - accuracy: 0.9186 - val_loss: 0.1976 - val_accuracy: 0.9214
# Epoch 65/1000
# 179/179 [==============================] - 66s 371ms/step - loss: 0.2364 - accuracy: 0.9167 - val_loss: 0.1861 - val_accuracy: 0.9214
# Epoch 66/1000
# 179/179 [==============================] - 67s 374ms/step - loss: 0.2263 - accuracy: 0.9200 - val_loss: 0.3052 - val_accuracy: 0.8909
# Epoch 67/1000
# 179/179 [==============================] - 66s 366ms/step - loss: 0.2209 - accuracy: 0.9245 - val_loss: 0.2026 - val_accuracy: 0.9222
# Epoch 68/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.2218 - accuracy: 0.9245 - val_loss: 0.4323 - val_accuracy: 0.8520
# Epoch 69/1000
# 179/179 [==============================] - 67s 372ms/step - loss: 0.2398 - accuracy: 0.9160 - val_loss: 0.2541 - val_accuracy: 0.9001
# Epoch 70/1000
# 179/179 [==============================] - 69s 383ms/step - loss: 0.2319 - accuracy: 0.9209 - val_loss: 0.1724 - val_accuracy: 0.9413
# Epoch 71/1000
# 179/179 [==============================] - 68s 383ms/step - loss: 0.2102 - accuracy: 0.9277 - val_loss: 0.2156 - val_accuracy: 0.9130
# Epoch 72/1000
# 179/179 [==============================] - 72s 400ms/step - loss: 0.2559 - accuracy: 0.9125 - val_loss: 0.1727 - val_accuracy: 0.9344
# Epoch 73/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.2144 - accuracy: 0.9223 - val_loss: 0.2193 - val_accuracy: 0.9260
# Epoch 74/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.2126 - accuracy: 0.9259 - val_loss: 0.2749 - val_accuracy: 0.9054
# Epoch 75/1000
# 179/179 [==============================] - 68s 379ms/step - loss: 0.2147 - accuracy: 0.9265 - val_loss: 0.1939 - val_accuracy: 0.9275
# Epoch 76/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.1952 - accuracy: 0.9329 - val_loss: 0.2886 - val_accuracy: 0.9092
# Epoch 77/1000
# 179/179 [==============================] - 67s 375ms/step - loss: 0.1942 - accuracy: 0.9301 - val_loss: 0.2513 - val_accuracy: 0.9146
# Epoch 78/1000
# 179/179 [==============================] - 68s 380ms/step - loss: 0.1928 - accuracy: 0.9331 - val_loss: 0.1558 - val_accuracy: 0.9489
# Epoch 79/1000
# 179/179 [==============================] - 68s 378ms/step - loss: 0.2060 - accuracy: 0.9275 - val_loss: 0.3798 - val_accuracy: 0.8795
# Epoch 80/1000
# 179/179 [==============================] - 68s 382ms/step - loss: 0.2096 - accuracy: 0.9277 - val_loss: 0.1547 - val_accuracy: 0.9466
# Epoch 81/1000
# 179/179 [==============================] - 70s 392ms/step - loss: 0.2004 - accuracy: 0.9315 - val_loss: 0.2381 - val_accuracy: 0.9085
# Epoch 82/1000
# 179/179 [==============================] - 67s 375ms/step - loss: 0.1817 - accuracy: 0.9352 - val_loss: 0.2074 - val_accuracy: 0.9138
# Epoch 83/1000
# 179/179 [==============================] - 68s 380ms/step - loss: 0.1878 - accuracy: 0.9382 - val_loss: 0.2005 - val_accuracy: 0.9291
# Epoch 84/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.2191 - accuracy: 0.9233 - val_loss: 0.2454 - val_accuracy: 0.9047
# Epoch 85/1000
# 179/179 [==============================] - 70s 393ms/step - loss: 0.1900 - accuracy: 0.9329 - val_loss: 0.1694 - val_accuracy: 0.9321
# Epoch 86/1000
# 179/179 [==============================] - 71s 397ms/step - loss: 0.1777 - accuracy: 0.9386 - val_loss: 0.2074 - val_accuracy: 0.9153
# Epoch 87/1000
# 179/179 [==============================] - 71s 398ms/step - loss: 0.1735 - accuracy: 0.9407 - val_loss: 0.1688 - val_accuracy: 0.9352
# Epoch 88/1000
# 179/179 [==============================] - 70s 392ms/step - loss: 0.1889 - accuracy: 0.9310 - val_loss: 0.1664 - val_accuracy: 0.9298
# Epoch 89/1000
# 179/179 [==============================] - 70s 393ms/step - loss: 0.1909 - accuracy: 0.9363 - val_loss: 0.2087 - val_accuracy: 0.9207
# Epoch 90/1000
# 179/179 [==============================] - 72s 402ms/step - loss: 0.1697 - accuracy: 0.9403 - val_loss: 0.2749 - val_accuracy: 0.8986
# Epoch 91/1000
# 179/179 [==============================] - 73s 408ms/step - loss: 0.1821 - accuracy: 0.9389 - val_loss: 0.1777 - val_accuracy: 0.9359
# Epoch 92/1000
# 179/179 [==============================] - 70s 389ms/step - loss: 0.2021 - accuracy: 0.9294 - val_loss: 0.1820 - val_accuracy: 0.9252
# Epoch 93/1000
# 179/179 [==============================] - 69s 385ms/step - loss: 0.1800 - accuracy: 0.9366 - val_loss: 0.1503 - val_accuracy: 0.9413
# Epoch 94/1000
# 179/179 [==============================] - 68s 379ms/step - loss: 0.1722 - accuracy: 0.9403 - val_loss: 0.1510 - val_accuracy: 0.9436
# Epoch 95/1000
# 179/179 [==============================] - 69s 386ms/step - loss: 0.1647 - accuracy: 0.9429 - val_loss: 0.2095 - val_accuracy: 0.9230
# Epoch 96/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.1813 - accuracy: 0.9373 - val_loss: 0.2489 - val_accuracy: 0.9230
# Epoch 97/1000
# 179/179 [==============================] - 68s 378ms/step - loss: 0.1636 - accuracy: 0.9443 - val_loss: 0.1925 - val_accuracy: 0.9260
# Epoch 98/1000
# 179/179 [==============================] - 68s 378ms/step - loss: 0.1669 - accuracy: 0.9424 - val_loss: 0.1379 - val_accuracy: 0.9489
# Epoch 99/1000
# 179/179 [==============================] - 69s 382ms/step - loss: 0.1912 - accuracy: 0.9340 - val_loss: 0.1809 - val_accuracy: 0.9375
# Epoch 100/1000
# 179/179 [==============================] - 68s 380ms/step - loss: 0.1813 - accuracy: 0.9403 - val_loss: 0.1827 - val_accuracy: 0.9367
# Epoch 101/1000
# 179/179 [==============================] - 68s 381ms/step - loss: 0.1659 - accuracy: 0.9468 - val_loss: 0.1459 - val_accuracy: 0.9481
# Epoch 102/1000
# 179/179 [==============================] - 69s 387ms/step - loss: 0.1725 - accuracy: 0.9415 - val_loss: 0.1941 - val_accuracy: 0.9306
# Epoch 103/1000
# 179/179 [==============================] - 66s 369ms/step - loss: 0.1607 - accuracy: 0.9429 - val_loss: 0.1394 - val_accuracy: 0.9481
# Epoch 104/1000
# 179/179 [==============================] - 68s 379ms/step - loss: 0.1510 - accuracy: 0.9480 - val_loss: 0.1405 - val_accuracy: 0.9458
# Epoch 105/1000
# 179/179 [==============================] - 67s 373ms/step - loss: 0.1699 - accuracy: 0.9454 - val_loss: 0.2918 - val_accuracy: 0.9031
# Epoch 106/1000
# 179/179 [==============================] - 67s 374ms/step - loss: 0.1696 - accuracy: 0.9403 - val_loss: 0.1660 - val_accuracy: 0.9375
# Epoch 107/1000
# 179/179 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9461
#
#
# Validation accuracy reached 95.12%. Training is stopped.
# 179/179 [==============================] - 67s 374ms/step - loss: 0.1619 - accuracy: 0.9461 - val_loss: 0.1394 - val_accuracy: 0.9512

# %%
total_time = end_time - start_time
print(f"Total time taken for training: {total_time:.2f} seconds")
# Out:
# Total time taken for training: 7658.29 seconds

# %%
# Training Loss Vs Validation Loss
# I have mentioned two different ways to plot the graphs, please take a look on both
loss = BTD.history.history['loss']
val_loss = BTD.history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label = 'loss')
plt.plot(epochs, val_loss, 'r', label = 'val_loss')
plt.title('Training Vs Validation Loss')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Accuracy Vs Validation Accuracy
# This is other way of plotting the plot
losses = pd.DataFrame(BTD.history.history)
losses[['accuracy','val_accuracy']].plot()
plt.title('Accuracy Vs Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
losses = pd.DataFrame(BTD.history.history)
losses[['accuracy', 'val_accuracy']] *= 100  # Convert to percentage
losses[['accuracy', 'val_accuracy']].plot()
plt.title('Accuracy Vs Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy (%)')  # Modify the y-axis label
plt.legend()
plt.show()

# %%
predictions = BTD.predict(testing_images)
print(predictions)
# Out:
# 41/41 [==============================] - 3s 67ms/step
# [[9.6354884e-01 3.4453150e-02 2.7049796e-04 1.7276153e-03]
#  [9.9054223e-01 7.8277150e-03 1.0794172e-04 1.5220859e-03]
#  [1.0000000e+00 1.8253784e-08 1.3675532e-14 1.0824713e-11]
#  ...
#  [1.6025992e-03 2.0844257e-03 1.3884520e-02 9.8242849e-01]
#  [5.6433473e-05 2.5832385e-04 4.6905436e-05 9.9963832e-01]
#  [1.6687486e-04 2.6941150e-03 6.8051663e-06 9.9713218e-01]]

# %%
print(BTD.evaluate(testing_images))
# Out:
# 41/41 [==============================] - 3s 67ms/step - loss: 0.1394 - accuracy: 0.9512
# [0.13944780826568604, 0.9511823058128357]

# %%
BTD.save('saved_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
BTD.save('saved_model.keras')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    testing_set,
    target_size=(192, 192),
    batch_size = 32,
    class_mode = 'categorical',
    shuffle=False
)

true_labels = test_generator.classes
num_samples = len(true_labels)

num_batches = num_samples // test_generator.batch_size
print("Total number of samples:", num_samples)
print("\n")

print("Number of batches:", num_batches)
predictions = BTD.predict(test_generator, steps = num_batches, verbose = 1)
# When verbose = 1, it will show a progress bar during the prediction
print("40 Batches are processed")
print("\n")
print("Number of batches:", num_batches + 1)
predictions = BTD.predict(test_generator, steps = num_batches + 1, verbose = 1)
print("41 Batches are processed (Same Batches)")
print("\n")
print("Number of batches:", num_batches + 1)
predictions = BTD.predict(test_generator, steps = num_samples // test_generator.batch_size + 1, verbose = 1)
predicted_labels = np.argmax(predictions, axis = 1)
print("41 Batches are processed (Same Batches)")
print("\n")

actual_label = len(true_labels)
pred_label = len(predicted_labels)
print(f"True Labels: {actual_label}\nPredicted Labels: {pred_label}")
cm = confusion_matrix(true_labels, predicted_labels)
class_names = ["Glioma", "Meningioma", "Notumor", "Pituitary"]

def plot_confusion_matrix(cm, classes, normalize = False, title = 'Confusion matrix', cmap = plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("\n")
        print("First Matrix is Normalized Confusion Matrix\n")
    else:
        print('Second Confusion Matrix is Without Normalization')

    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()

plt.figure()
plot_confusion_matrix(cm, classes = class_names, normalize = True, title = 'Normalized Confusion Matrix')

plt.figure()
plot_confusion_matrix(cm, classes = class_names, normalize = False, title = 'Confusion Matrix without Normalization')

plt.show()
# Out:
# Found 1311 images belonging to 4 classes.
# Total number of samples: 1311
#
#
# Number of batches: 40
# 40/40 [==============================] - 3s 79ms/step
# 40 Batches are processed
#
#
# Number of batches: 41
# 41/41 [==============================] - 2s 55ms/step
# 41 Batches are processed (Same Batches)
#
#
# Number of batches: 41
# 41/41 [==============================] - 2s 56ms/step
# 41 Batches are processed (Same Batches)
#
#
# True Labels: 1311
# Predicted Labels: 1311
#
#
# First Matrix is Normalized Confusion Matrix
#
# Second Confusion Matrix is Without Normalization
